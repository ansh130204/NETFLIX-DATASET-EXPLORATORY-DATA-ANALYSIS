# %% [markdown]
# ### EDA Project
# Exploratory Data Analysis on Netflix Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
netflix=pd.read_csv(r"C:\Users\ansha\Downloads\archive\netflix_titles.csv",index_col=0)
netflix
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ### Step 1: Dataset Information

# %%
# Shape and info
print("Dataset Shape:", netflix.shape)
netflix.info()

# Check for missing values
netflix.isnull().sum().sort_values(ascending=False)

# Basic statistics
netflix.describe(include='all')
# Out:
# Dataset Shape: (8807, 11)
# <class 'pandas.core.frame.DataFrame'>
# Index: 8807 entries, s1 to s8807
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8807 non-null   object
#  1   title         8807 non-null   object
#  2   director      6173 non-null   object
#  3   cast          7982 non-null   object
#  4   country       7976 non-null   object
#  5   date_added    8797 non-null   object
#  6   release_year  8807 non-null   int64
#  7   rating        8803 non-null   object
#  8   duration      8804 non-null   object
#  9   listed_in     8807 non-null   object
#  10  description   8807 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 825.7+ KB
#          type                 title       director                cast  \
# count    8807                  8807           6173                7982
# unique      2                  8807           4528                7692
# ...

# %% [markdown]
# ### Insights:
#
# The dataset contains information about Netflix Movies and TV Shows.
#
# There are missing values in columns like director and cast.

# %% [markdown]
# ### Step 2: Data Cleaning

# %%
# Remove duplicates
netflix.drop_duplicates(inplace=True)

# Handle missing values
netflix['country'].fillna('Unknown', inplace=True)
netflix['rating'].fillna('Not Rated', inplace=True)

# Convert date_added to datetime
netflix['date_added'] = pd.to_datetime(netflix['date_added'],errors='coerce')

# Extract year and month
netflix['year_added'] = netflix['date_added'].dt.year
netflix['month_added'] = netflix['date_added'].dt.month

netflix
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ## Step 3. Univariate Analysis
# ### 3.1 Type of Content

# %%
sns.countplot(data=netflix, x='type', palette='Set2')
plt.title('Distribution of Movies and TV Shows on Netflix')
plt.xlabel('Type of Content')
plt.ylabel('Count')
plt.show()

netflix['type'].value_counts(normalize=True)*100
# Out:
# type
# Movie      69.615079
# TV Show    30.384921
# Name: proportion, dtype: float64

# %% [markdown]
# ## Insights:
#
# Netflix’s catalog is dominated by Movies, forming about 70% of total titles.
#
# TV Shows form a smaller segment but are growing gradually — reflecting Netflix’s investment in series and original productions.
#
# This indicates a strong focus on movie licensing and original TV content expansion.

# %% [markdown]
# ## 3.2 Ratings Distribution

# %%
sns.countplot(data=netflix, x='rating',
              order=netflix['rating'].value_counts().index, palette='viridis')
plt.title('Distribution of Ratings on Netflix')
plt.xticks(rotation=45)
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Insights:
#
# The most common rating is TV-MA, showing that Netflix largely targets mature audiences.
#
# Other frequent ratings include TV-14 and R, further confirming the focus on adult and teenage content.
#
# Children’s content (TV-Y, TV-G) is less represented, suggesting Netflix’s niche in general entertainment and mature drama rather than kids’ shows.

# %% [markdown]
# ## Step 4. Country-wise Analysis

# %%
top_countries = netflix['country'].value_counts().head(10)

sns.barplot(x=top_countries.values, y=top_countries.index, palette="flare")
plt.title('Top 10 Content-Producing Countries on Netflix')
plt.xlabel('Number of Titles')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# ## Insight:
# The United States leads by a wide margin, followed by India, United Kingdom, Canada, and Japan.
#
# This trend shows Netflix’s American origin dominance, while also revealing significant growth in Asian content, particularly from India and Japan.
#
# Indicates a global diversification strategy in Netflix’s library.

# %% [markdown]
# ## Step 5. Year-wise Additions

# %%
netflix['year_added'].value_counts().sort_index().plot(kind='bar', color='salmon')
plt.title('Number of Titles Added Each Year')
plt.xlabel('Year Added')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Insights:
# A noticeable spike in content additions between 2016 and 2020 shows Netflix’s massive expansion phase.
#
# The platform added the highest volume of new content around 2019, coinciding with global expansion and increased original productions.
#
# A small decline after 2020 likely reflects COVID-19-related production halts.

# %% [markdown]
# ## Step 6. Genre Analysis

# %%
genres = netflix['listed_in'].str.split(',').explode().str.strip().value_counts().head(15)

sns.barplot(x=genres.values, y=genres.index, palette="magma")
plt.title('Top 15 Genres on Netflix')
plt.xlabel('Number of Titles')
plt.ylabel('Genre')
plt.show()

# %% [markdown]
# ## Insights:
# International Movies, Dramas, and Comedies dominate Netflix’s catalog, showing the platform’s focus on globally appealing and story-driven content.
#
# The strong presence of International TV Shows and Documentaries highlights Netflix’s growing investment in diverse, cross-cultural, and factual entertainment.
#
# A mix of Action, Romance, and Family genres reflects Netflix’s effort to balance mainstream entertainment with content for varied audience preferences.

# %% [markdown]
# ## Step 7. Duration Analysis (Movies Only)

# %%
movies = netflix[netflix['type'] == 'Movie']
movies['duration'] = movies['duration'].str.replace(' min', '').astype(float)

sns.histplot(movies['duration'], bins=30, color='orange')
plt.title('Distribution of Movie Durations')
plt.xlabel('Duration (Minutes)')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\ansha\AppData\Local\Temp\ipykernel_6404\503211636.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['duration'] = movies['duration'].str.replace(' min', '').astype(float)

# %% [markdown]
# ## Insights:
# Most Netflix movies have a duration between 80 to 120 minutes, showing that the platform favors standard feature-length films.
#
# The distribution is right-skewed, meaning very few movies exceed 150 minutes, as longer runtimes are less common among Netflix titles.
#
# The concentration around 90–100 minutes indicates Netflix’s preference for compact, easily consumable movies suited for a broad streaming audience.

# %% [markdown]
# ## Step 8. Directors with Most Titles

# %%
top_directors = netflix['director'].value_counts().head(10)

sns.barplot(x=top_directors.values, y=top_directors.index, palette='crest')
plt.title('Top 10 Directors with Most Netflix Titles')
plt.xlabel('Number of Titles')
plt.ylabel('Director')
plt.show()

# %% [markdown]
# ### Insights
# Rajiv Chilaka leads with the highest number of Netflix titles, reflecting the platform’s emphasis on animated and family-oriented Indian content.
#
# Raúl Campos and Jan Suter follow closely, indicating Netflix’s investment in Latin American entertainment and diverse global content.
#
# The list includes both international and Hollywood directors (like Martin Scorsese and Steven Spielberg), showing Netflix’s balance between regional and global cinematic appeal.
